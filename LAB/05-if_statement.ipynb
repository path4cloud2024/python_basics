# %% [markdown]
# ## In Python, a condition is a expression that results in a Boolean Value of Capital T True or Capital F False

# %%
10 > 5
# Out:
# True

# %%
10 < 5
# Out:
# False

# %%
print(10 == 5, 10 != 5, 10 > 5, 10 >= 5, 10 > 5, 10 <= 5)
# Out:
# False True True True True False

# %% [markdown]
# # If statement syntax

# %% [markdown]
# #### - If is a staic keyword, already reserved in Python.
# #### - when we start the if statement then we need to define the condition using operator which we discussed above.
# #### - after condtion, if statement must be closed with colon (:), called as suite which tells the python to maintain the indendation for further statement after colon
# #### - we normaly uses 4 white spaces as space under if statement to maintain the statement
# #### - you can keep any number of spaces for indentation but it must be persistent across all statement
# #### - we can close or omit the spaces to close the simple if statement

# %%
num1 = 10
num2 = 5

# %%
num1
# Out:
# 10

# %%
num2
# Out:
# 5

# %%
if num1 == num2:
    print(num1, 'is equal to', num2)

if num1 != num2:
    print(num1, 'is not equal to', num2)

if num1 > num2:
    print(num1, 'is greater than', num2)

if num1 >= num2:
    print(num1, 'is greater than or equal to', num2)

if num1 < num2:
    print(num1, 'is less than', num2)

if num1 <= num2:
    print(num1,'is less than or equal to', num2)
# Out:
# 10 is not equal to 5
# 10 is greater than 5
# 10 is greater than or equal to 5

# %% [markdown]
# #### mixed operator to check the range in conditions

# %%
num3 = 2

# %%
1 <= num3 <= 10
# Out:
# True

# %%
num4 = 12

# %%
1 <= num4 <= 10
# Out:
# False

# %%
## check a given number in range or not

num4 = int(input("enter any number: "))
# Out:
# enter any number:  23

# %%
if 1 <= num4 <= 100:
    print ("given number", num4, "is in range of 1 to 100")
# Out:
# given number 23 is in range of 1 to 100

# %% [markdown]
# # Time to check
# - Write a snippet which will accept the two values from user and assign those to 'first' and 'second' variable.
# - try to find which word comes first

# %%
# Solution
first = input('Enter first word: ')
second = input('Enter second word: ')
if first < second:
    print(first + ' comes before ' + second)
else:
    print(second + ' comes before ' + first)
# Out:
# Enter first word:  abc
# Enter second word:  def
# abc comes before def

# %% [markdown]
# # if else and if .. elif .. else syntax

# %%
age = int(input("enter your age: "))
# Out:
# enter your age:  23

# %%
if age >= 18:
    print("you are eligible to apply for DL")
else:
    print("you have to wait until 18, you are not eligible")
# Out:
# you are eligible to apply for DL

# %%
## Conditional Expresssion
marks = 9
result = ('Pass' if marks >=72 else 'Not Pass')
result
# Out:
# 'Not Pass'

# %%
## elif example
score = int(input("enter your score: "))

if score >= 90:
    print("Gold Medal")
elif score >=75:
    print("Silver Medal")
elif score >=50:
    print("Bronze Medal")
else:
    print("Not Qualified")
# Out:
# enter your score:  97
# Gold Medal

# %% [markdown]
# # More Complex Statements
# - If we want to check that two things are both **TRUE**, then we can use **and**
# - If we want to check that one of two things is **TRUE**, then we can use **or**

# %%
t1 = 10
t2 = 20
# TRUE and TRUE --> TRUE
t1 == 10 and t2 == 20
# Out:
# True

# %%
# TRUE and FALSE --> FALSE
t1 == 10 and t2 == 30
# Out:
# False

# %%
# TRUE or FALSE --> TRUE
t1 == 10 or t2 == 30
# Out:
# True
