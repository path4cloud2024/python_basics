# %% [markdown]
# ## Random Library

# %%
import random

# %%
random.random()
# Out:
# 0.18134647395344716

# %% [raw]
# In below for loop, we are running it for a range upto 10, means 10 times and then using random.randrange, we are printing 1 number from a range again 1-7.
# so here, random.randrange(1, 7) means, it will print 1 number from 1-7 any random number.

# %%
for num in range(10):
    print(random.randrange(1, 7), end=' ')
# Out:
# 4 1 1 4 1 5 3 4 6 6

# %%
for num in range(10):
    print(random.randrange(1, 7), end=' ')
# Out:
# 2 6 2 5 2 6 2 2 6 3

# %%
random.randrange(1, 4)
# Out:
# 2

# %% [raw]
# ## lets create rolling dice program:

# %%
import random
# dice face
star = '*'

for rolling in range(1):
    dice_face = random.randrange(1, 7)

print('Your dice face is \n')
print(f'{star:>4}{star:>4}{star:>4}')
print(f'{star:>4}{dice_face:>4}{star:>4}')
print(f'{star:>4}{star:>4}{star:>4}')
# Out:
# Your dice face is
#
#    *   *   *
#    *   5   *
#    *   *   *

# %% [raw]
# import random
# # dice face
# star = '*'
#
# for rolling in range(1):
#     dice_face = random.randrange(1, 7)
#
# if dice_face == 1:
#     print(f' ')
#     print(f'   {star}')
#     print(f' ')
# if dice_face == 2:
#     print(f'        {star}')
#     print(f'')
#     print(f'{star}')
# if dice_face == 3:
#     print(f'{star}')
#     print(f'    {star}')
#     print(f'        {star}')
# if dice_face == 4:
#     print(f'{star}       {star}')
#     print(f'')
#     print(f'{star}       {star}')
# if dice_face == 5:
#     print(f'{star}       {star}')
#     print(f'    {star}')
#     print(f'{star}       {star}')
# if dice_face == 6:
#     print(f'{star}   {star}   {star}')
#     print(f'{star}   {star}   {star}')
#     print(f'{star}   {star}   {star}')

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 1 2 1 2 1

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 2 2 1 1 1

# %% [markdown]
# ### SEED Function

# %% [raw]
# from this point, will introduce the seed function and from now onwards, will run the foor loop for 3 times, will get each time
# new values, then will again run the seed fuction, we will see, then all 3 values were be repeated.

# %%
random.seed(3)

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 1 1 2 2 1

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 1 2 2 1 1

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 2 2 2 1 1

# %% [raw]
# Repeating the same seed funciton with same value, now you can see, we are getting the same value from first
# run of for loop after seed functions above

# %%
random.seed(3)

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 1 1 2 2 1

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 1 2 2 1 1

# %%
for new_num in range(5):
    print(random.randrange(1,3), end=' ')
# Out:
# 2 2 2 1 1

# %% [raw]
# here, random.seed(3) is a random generator and each time will give you a unique range of random numbers (usign some internal
# calculation). until you call it generator again, it will keep on giving random range but once you recalled it, again the same sequecne of random range will be followed which was already generated

# %%
## write a code to flip the coin to 10 times, and print H for Head and T for Tail:
for i in range(10):
    print('H' if random.randrange(2) == 0 else 'T', end=' ') # here, random.randrange(2) will produce either 0 or 1
# Out:
# H T H T T T T T T H
