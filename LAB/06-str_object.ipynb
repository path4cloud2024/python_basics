# %% [markdown]
# ## STR Class Objects

# %%
a1 = 'hello'

# %%
a2 = ' there'

# %%
a3 = ''

# %%
len(a1)

# %%
a3

# %%
a3 = a1 + a2

# %%
a3

# %%
len(a3)

# %% [markdown]
# ### Standalone functions (METHODS)

# %%
a1.startswith('he')

# %%
a1.endswith('lo')

# %%
a1.endswith('LO')
